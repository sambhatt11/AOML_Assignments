# %%
import pandas as pd

# %%
df = pd.read_csv('StarClassificationDataset.csv')
# Out:
# <ipython-input-2-bca518d0a62f>:1: DtypeWarning: Columns (1,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('StarClassificationDataset.csv')

# %%
df
# Out:
#           object_ID        alpha      delta  UV_filter  green_filter  \
# 0      1.240000e+18  135.6891066  32.494632   23.87882      22.27530
# 1      1.240000e+18  144.8261006  31.274185   24.77759      22.83188
# 2      1.240000e+18  142.1887896  35.582444   25.26307      22.66389
# 3      1.240000e+18  338.7410378  -0.402828   22.13682      23.77656
# 4      1.240000e+18  345.2825932  21.183866   19.43718      17.58028
# ...             ...          ...        ...        ...           ...
# 99995  1.240000e+18    39.620709  -2.594074   22.16759      22.97586
# 99996  1.240000e+18    29.493819  19.798874   22.69118      22.38628
# 99997  1.240000e+18   224.587407  15.700707   21.16916      19.26997
# 99998  1.240000e+18   212.268621  46.660365   25.35039      21.63757
# 99999  1.240000e+18   196.896053  49.464643   22.62171      21.79745
#
#        red_filter  near_IR_filter  IR_filter run_ID  rerun_ID  cam_col  \
# 0        20.39501        19.16573   18.79371   3606       301        2
# 1        22.58444        21.16812   21.61427   4518       301        5
# 2        20.60976        19.34857   18.94827   3606       301        2
# 3        21.61162        20.50454   19.25010   4192       301        3
# 4        16.49747        15.97711   15.54461    NaN       301        3
# ...           ...             ...        ...    ...       ...      ...
# 99995    21.90404        21.30548   20.73569   7778       301        2
# 99996    20.45003        19.75759   19.41526   7917       301        1
# 99997    18.20428        17.69034   17.35221   5314       301        4
# 99998    19.91386        19.07254   18.62482   3650       301        4
# 99999    20.60115        20.00959   19.28075   3650       301        4
#
#        field_ID   spec_obj_ID  red_shift  plate_ID    MJD  fiber_ID   class
# 0            79  6.540000e+18   0.634794      5812  56354       171  GALAXY
# 1           119  1.180000e+19   0.779136     10445  58158       427  GALAXY
# 2           120  5.150000e+18   0.644195      4576  55592       299  GALAXY
# 3           214  1.030000e+19   0.932346      9149  58039       775  GALAXY
# 4           137  6.890000e+18   0.116123      6121  56187       842  GALAXY
# ...         ...           ...        ...       ...    ...       ...     ...
# 99995       581  1.060000e+19   0.000000      9374  57749       438  GALAXY
# 99996       289  8.590000e+18   0.404895      7626  56934       866  GALAXY
# 99997       308  3.110000e+18   0.143366      2764  54535        74  GALAXY
# 99998       131  7.600000e+18   0.455040      6751  56368       470  GALAXY
# 99999        60  8.340000e+18   0.542944      7410  57104       851  GALAXY
#
# [100000 rows x 18 columns]

# %%
df.isna().sum()
# Out:
# object_ID         0
# alpha             1
# delta             2
# UV_filter         0
# green_filter      0
# red_filter        0
# near_IR_filter    0
# IR_filter         0
# run_ID            6
# rerun_ID          0
# cam_col           0
# field_ID          0
# spec_obj_ID       0
# red_shift         0
# plate_ID          0
# MJD               0
# fiber_ID          0
# class             0
# dtype: int64

# %%
df.dropna()
# Out:
#           object_ID        alpha      delta  UV_filter  green_filter  \
# 0      1.240000e+18  135.6891066  32.494632   23.87882      22.27530
# 1      1.240000e+18  144.8261006  31.274185   24.77759      22.83188
# 2      1.240000e+18  142.1887896  35.582444   25.26307      22.66389
# 3      1.240000e+18  338.7410378  -0.402828   22.13682      23.77656
# 5      1.240000e+18  340.9951205  20.589476   23.48827      23.33776
# ...             ...          ...        ...        ...           ...
# 99995  1.240000e+18    39.620709  -2.594074   22.16759      22.97586
# 99996  1.240000e+18    29.493819  19.798874   22.69118      22.38628
# 99997  1.240000e+18   224.587407  15.700707   21.16916      19.26997
# 99998  1.240000e+18   212.268621  46.660365   25.35039      21.63757
# 99999  1.240000e+18   196.896053  49.464643   22.62171      21.79745
#
#        red_filter  near_IR_filter  IR_filter run_ID  rerun_ID  cam_col  \
# 0        20.39501        19.16573   18.79371   3606       301        2
# 1        22.58444        21.16812   21.61427   4518       301        5
# 2        20.60976        19.34857   18.94827   3606       301        2
# 3        21.61162        20.50454   19.25010   4192       301        3
# 5        21.32195        20.25615   19.54544   8102       301        3
# ...           ...             ...        ...    ...       ...      ...
# 99995    21.90404        21.30548   20.73569   7778       301        2
# 99996    20.45003        19.75759   19.41526   7917       301        1
# 99997    18.20428        17.69034   17.35221   5314       301        4
# 99998    19.91386        19.07254   18.62482   3650       301        4
# 99999    20.60115        20.00959   19.28075   3650       301        4
#
#        field_ID   spec_obj_ID  red_shift  plate_ID    MJD  fiber_ID   class
# 0            79  6.540000e+18   0.634794      5812  56354       171  GALAXY
# 1           119  1.180000e+19   0.779136     10445  58158       427  GALAXY
# 2           120  5.150000e+18   0.644195      4576  55592       299  GALAXY
# 3           214  1.030000e+19   0.932346      9149  58039       775  GALAXY
# 5           110  5.660000e+18   1.424659      5026  55855       741     QSO
# ...         ...           ...        ...       ...    ...       ...     ...
# 99995       581  1.060000e+19   0.000000      9374  57749       438  GALAXY
# 99996       289  8.590000e+18   0.404895      7626  56934       866  GALAXY
# 99997       308  3.110000e+18   0.143366      2764  54535        74  GALAXY
# 99998       131  7.600000e+18   0.455040      6751  56368       470  GALAXY
# 99999        60  8.340000e+18   0.542944      7410  57104       851  GALAXY
#
# [99991 rows x 18 columns]

# %%
df.isna().sum()
# Out:
# object_ID         0
# alpha             1
# delta             2
# UV_filter         0
# green_filter      0
# red_filter        0
# near_IR_filter    0
# IR_filter         0
# run_ID            6
# rerun_ID          0
# cam_col           0
# field_ID          0
# spec_obj_ID       0
# red_shift         0
# plate_ID          0
# MJD               0
# fiber_ID          0
# class             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   object_ID       100000 non-null  float64
#  1   alpha           99999 non-null   object
#  2   delta           99998 non-null   float64
#  3   UV_filter       100000 non-null  float64
#  4   green_filter    100000 non-null  float64
#  5   red_filter      100000 non-null  float64
#  6   near_IR_filter  100000 non-null  float64
#  7   IR_filter       100000 non-null  float64
#  8   run_ID          99994 non-null   object
#  9   rerun_ID        100000 non-null  int64
#  10  cam_col         100000 non-null  int64
#  11  field_ID        100000 non-null  int64
#  12  spec_obj_ID     100000 non-null  float64
#  13  red_shift       100000 non-null  float64
#  14  plate_ID        100000 non-null  int64
#  15  MJD             100000 non-null  int64
#  16  fiber_ID        100000 non-null  int64
#  17  class           100000 non-null  object
# dtypes: float64(9), int64(6), object(3)
# memory usage: 13.7+ MB

# %%
X =df.drop('class',axis =1)
y = df['class']

# %%
X
# Out:
#           object_ID        alpha      delta  UV_filter  green_filter  \
# 0      1.240000e+18  135.6891066  32.494632   23.87882      22.27530
# 1      1.240000e+18  144.8261006  31.274185   24.77759      22.83188
# 2      1.240000e+18  142.1887896  35.582444   25.26307      22.66389
# 3      1.240000e+18  338.7410378  -0.402828   22.13682      23.77656
# 4      1.240000e+18  345.2825932  21.183866   19.43718      17.58028
# ...             ...          ...        ...        ...           ...
# 99995  1.240000e+18    39.620709  -2.594074   22.16759      22.97586
# 99996  1.240000e+18    29.493819  19.798874   22.69118      22.38628
# 99997  1.240000e+18   224.587407  15.700707   21.16916      19.26997
# 99998  1.240000e+18   212.268621  46.660365   25.35039      21.63757
# 99999  1.240000e+18   196.896053  49.464643   22.62171      21.79745
#
#        red_filter  near_IR_filter  IR_filter run_ID  rerun_ID  cam_col  \
# 0        20.39501        19.16573   18.79371   3606       301        2
# 1        22.58444        21.16812   21.61427   4518       301        5
# 2        20.60976        19.34857   18.94827   3606       301        2
# 3        21.61162        20.50454   19.25010   4192       301        3
# 4        16.49747        15.97711   15.54461    NaN       301        3
# ...           ...             ...        ...    ...       ...      ...
# 99995    21.90404        21.30548   20.73569   7778       301        2
# 99996    20.45003        19.75759   19.41526   7917       301        1
# 99997    18.20428        17.69034   17.35221   5314       301        4
# 99998    19.91386        19.07254   18.62482   3650       301        4
# 99999    20.60115        20.00959   19.28075   3650       301        4
#
#        field_ID   spec_obj_ID  red_shift  plate_ID    MJD  fiber_ID
# 0            79  6.540000e+18   0.634794      5812  56354       171
# 1           119  1.180000e+19   0.779136     10445  58158       427
# 2           120  5.150000e+18   0.644195      4576  55592       299
# 3           214  1.030000e+19   0.932346      9149  58039       775
# 4           137  6.890000e+18   0.116123      6121  56187       842
# ...         ...           ...        ...       ...    ...       ...
# 99995       581  1.060000e+19   0.000000      9374  57749       438
# 99996       289  8.590000e+18   0.404895      7626  56934       866
# 99997       308  3.110000e+18   0.143366      2764  54535        74
# 99998       131  7.600000e+18   0.455040      6751  56368       470
# 99999        60  8.340000e+18   0.542944      7410  57104       851
#
# [100000 rows x 17 columns]

# %%
X["alpha"] = pd.to_numeric(X["alpha"], errors="coerce")
X["run_ID"] = pd.to_numeric(X["run_ID"], errors="coerce")

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   object_ID       100000 non-null  float64
#  1   alpha           99998 non-null   float64
#  2   delta           99998 non-null   float64
#  3   UV_filter       100000 non-null  float64
#  4   green_filter    100000 non-null  float64
#  5   red_filter      100000 non-null  float64
#  6   near_IR_filter  100000 non-null  float64
#  7   IR_filter       100000 non-null  float64
#  8   run_ID          99993 non-null   float64
#  9   rerun_ID        100000 non-null  int64
#  10  cam_col         100000 non-null  int64
#  11  field_ID        100000 non-null  int64
#  12  spec_obj_ID     100000 non-null  float64
#  13  red_shift       100000 non-null  float64
#  14  plate_ID        100000 non-null  int64
#  15  MJD             100000 non-null  int64
#  16  fiber_ID        100000 non-null  int64
# dtypes: float64(11), int64(6)
# memory usage: 13.0 MB

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
y_train
# Out:
# 93664       QSO
# 36604      STAR
# 13935    GALAXY
# 27891       QSO
# 44067       QSO
#           ...
# 71002    GALAXY
# 84488    GALAXY
# 30475    GALAXY
# 52498    GALAXY
# 48959       QSO
# Name: class, Length: 80000, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.97955

# %%
from sklearn.metrics import classification_report, confusion_matrix
mat =classification_report(y_test, y_pred)
mat
# Out:
# '              precision    recall  f1-score   support\n\n      GALAXY       0.98      0.99      0.98     11889\n         QSO       0.97      0.93      0.95      3792\n        STAR       0.99      1.00      1.00      4319\n\n    accuracy                           0.98     20000\n   macro avg       0.98      0.97      0.98     20000\nweighted avg       0.98      0.98      0.98     20000\n'

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[11732,   119,    38],
#        [  250,  3542,     0],
#        [    2,     0,  4317]])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 5))
plt.imshow(mat, cmap="Blues")
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a1df8ad15325> in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(6, 5))
# ----> 3 plt.imshow(mat, cmap="Blues")
#       4 plt.colorbar()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5943             self.set_aspect(aspect)
#    5944
# -> 5945         im.set_data(X)
#    5946         im.set_alpha(alpha)
#    5947         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in set_data(self, A)
#     673         if isinstance(A, PIL.Image.Image):
#     674             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 675         self._A = self._normalize_image_array(A)
#     676         self._imcache = None
#     677         self.stale = True
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _normalize_image_array(A)
#     636         A = cbook.safe_masked_invalid(A, copy=True)
#     637         if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 638             raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     639                             f"converted to float")
#     640         if A.ndim == 3 and A.shape[-1] == 1:
#
# TypeError: Image data of dtype <U380 cannot be converted to float
